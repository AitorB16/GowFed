# %%
import matplotlib
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import matplotlib.ticker as ticker
import configparser

# %%
#font = {'family' : 'normal',
#        'weight' : 'normal',
#        'size'   : 12}
#
#matplotlib.rc('font', **font)

# %%
MODE = 'fl' #fl
RUN_NAME = ['F1', 'F2', 'F3', 'F4', 'F5', 'F6']
EXP_NAME = ['GF_SB', 'GF_SU', 'GF_MB', 'GF_MU', 'GF_LB', 'GF_LU']
#PRINT_SCR
#BALANCE_DATA
#TRAIN_SIZE
#TEST_SIZE

# %%
path = {}

stats = {}
tr_loss = {}
val_loss = {}

cl_id = {}
ds_sizes = {}
accuracies = {}
prcsn = {}
rcl = {}
f1 = {}
roc = {}

for run in RUN_NAME:
    root = 'results/'
    path[run] = root + MODE + '/' + run + '/'
    
    stats = pd.read_csv(path[run] + 'stats.txt', sep='\s+')
    tr_loss[run] = pd.read_csv(path[run] + 'tr_loss.txt', sep='\s+', header = None).values[0]
    val_loss[run] = pd.read_csv(path[run] + 'val_loss.txt', sep='\s+', header = None).values[0]
    
    cl_id[run] = stats['CL_ID'].values
    ds_sizes[run] = stats['TRAIN_DS_SIZE'].values
    accuracies[run] = stats['ACC'].values
    prcsn[run] = stats['PREC'].values
    rcl[run] = stats['RCL'].values
    f1[run] = stats['F1'].values
    roc[run] = stats['ROC'].values

# %%
for run in RUN_NAME:
    
    '''PLOT DS SIZE'''
    plt.bar(x = cl_id[run], height=ds_sizes[run], log = True)
    plt.title('Dataset size in each node')
    plt.xlabel('Node ID')
    plt.ylabel('Number of instances')
    plt.savefig(path[run] + run + '_inst_num.eps', format='eps')
    plt.show()
    
    '''PLOT LOSS'''
    plt.plot(tr_loss[run])
    plt.plot(val_loss[run])
    plt.legend(["Training Loss", "Validation Loss"])
    plt.title('Model loss')
    plt.xlabel("Number of rounds")
    plt.ylabel("Loss")
    plt.savefig(path[run] + run + '_loss.eps', format='eps')
    plt.show()
    
    '''PLOT PR'''
    plt.rcParams["figure.figsize"] = [9.00, 5.50]
    plt.rcParams["figure.autolayout"] = True
    plt.xlim(0, 1)
    plt.ylim(0, 1)
    plt.grid()
    for i in range(0,len(cl_id[run])):
        x = rcl[run][i]
        y = prcsn[run][i]
        plt.plot(x, y, marker="D", markersize=10, markeredgecolor="black", markerfacecolor="coral")
    plt.title('Precision-Recall Space')
    plt.ylabel('Precision')
    plt.xlabel('Recall')
    plt.savefig(path[run] + run + '_pr.eps', format='eps')
    plt.show()
    
    '''PLOT ACCURACIES'''
    plt.bar(x = cl_id[run], height=accuracies[run], log = True)
    plt.title('Accuracies in each node')
    plt.xlabel('Node ID')
    plt.ylabel('Accuracy')
    plt.savefig(path[run] + run + '_acc.eps', format='eps')
    plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
#print(np.median(accuracies))

# %%
'''DS SIZE'''

figure, axis = plt.subplots(2, 3)

'''PLOT 1'''
axis[0, 0].bar(x = cl_id[RUN_NAME[0]], height=ds_sizes[RUN_NAME[0]], log = True)
axis[0, 0].set_title(EXP_NAME[0])
axis[0, 0].set_xlabel('Node ID')
axis[0, 0].set_ylabel('Number of instances')
axis[0, 0].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[0, 0].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[0, 0].set_ylim(2800,3150)

'''PLOT 2'''
axis[1, 0].bar(x = cl_id[RUN_NAME[1]], height=ds_sizes[RUN_NAME[1]], log = True)
axis[1, 0].set_title(EXP_NAME[1])
axis[1, 0].set_xlabel('Node ID')
axis[1, 0].set_ylabel('Number of instances')
axis[1, 0].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[1, 0].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[1, 0].set_ylim(2800,3150)



'''PLOT 3'''
axis[0, 1].bar(x = cl_id[RUN_NAME[2]], height=ds_sizes[RUN_NAME[2]], log = True)
axis[0, 1].set_title(EXP_NAME[2])
axis[0, 1].set_xlabel('Node ID')
axis[0, 1].set_ylabel('Number of instances')
axis[0, 1].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[0, 1].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[0, 1].set_ylim(2800,3150)


'''PLOT 4'''
axis[1, 1].bar(x = cl_id[RUN_NAME[3]], height=ds_sizes[RUN_NAME[3]], log = True)
axis[1, 1].set_title(EXP_NAME[3])
axis[1, 1].set_xlabel('Node ID')
axis[1, 1].set_ylabel('Number of instances')
axis[1, 1].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[1, 1].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[1, 1].set_ylim(2800,3150)


'''PLOT 5'''
axis[0, 2].bar(x = cl_id[RUN_NAME[4]], height=ds_sizes[RUN_NAME[4]], log = True)
axis[0, 2].set_title(EXP_NAME[4])
axis[0, 2].set_xlabel('Node ID')
axis[0, 2].set_ylabel('Number of instances')
axis[0, 2].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[0, 2].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[0, 2].set_ylim(2800,3150)


'''PLOT 6'''
axis[1, 2].bar(x = cl_id[RUN_NAME[5]], height=ds_sizes[RUN_NAME[5]], log = True)
axis[1, 2].set_title(EXP_NAME[5])
axis[1, 2].set_xlabel('Node ID')
axis[1, 2].set_ylabel('Number of instances')
axis[1, 2].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[1, 2].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[1, 2].set_ylim(2800,3150)


#plt.suptitle('Dataset size per node in ' + MODE.upper() + ' version')
plt.savefig('results/' + MODE + '/' + MODE + '_dssize_grid.svg', format='svg')
plt.show()

# %%
'''ACC'''

figure, axis = plt.subplots(2, 3)

'''PLOT 1'''
axis[0, 0].bar(x = cl_id[RUN_NAME[0]], height=accuracies[RUN_NAME[0]], log = True)
axis[0, 0].set_title(EXP_NAME[0])
axis[0, 0].set_xlabel('Node ID')
axis[0, 0].set_ylabel('Accuracy')
axis[0, 0].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[0, 0].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[0, 0].set_ylim(0.5,1)

'''PLOT 2'''
axis[1, 0].bar(x = cl_id[RUN_NAME[1]], height=accuracies[RUN_NAME[1]], log = True)
axis[1, 0].set_title(EXP_NAME[1])
axis[1, 0].set_xlabel('Node ID')
axis[1, 0].set_ylabel('Accuracy')
axis[1, 0].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[1, 0].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[1, 0].set_ylim(0.5,1)


'''PLOT 3'''
axis[0, 1].bar(x = cl_id[RUN_NAME[2]], height=accuracies[RUN_NAME[2]], log = True)
axis[0, 1].set_title(EXP_NAME[2])
axis[0, 1].set_xlabel('Node ID')
axis[0, 1].set_ylabel('Accuracy')
axis[0, 1].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[0, 1].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[0, 1].set_ylim(0.5,1)


'''PLOT 4'''
axis[1, 1].bar(x = cl_id[RUN_NAME[3]], height=accuracies[RUN_NAME[3]], log = True)
axis[1, 1].set_title(EXP_NAME[3])
axis[1, 1].set_xlabel('Node ID')
axis[1, 1].set_ylabel('Accuracy')
axis[1, 1].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[1, 1].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[1, 1].set_ylim(0.5,1)


'''PLOT 5'''
axis[0, 2].bar(x = cl_id[RUN_NAME[4]], height=accuracies[RUN_NAME[4]], log = True)
axis[0, 2].set_title(EXP_NAME[4])
axis[0, 2].set_xlabel('Node ID')
axis[0, 2].set_ylabel('Accuracy')
axis[0, 2].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[0, 2].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[0, 2].set_ylim(0.5,1)


'''PLOT 6'''
axis[1, 2].bar(x = cl_id[RUN_NAME[5]], height=accuracies[RUN_NAME[5]], log = True)
axis[1, 2].set_title(EXP_NAME[5])
axis[1, 2].set_xlabel('Node ID')
axis[1, 2].set_ylabel('Accuracy')
axis[1, 2].get_yaxis().set_minor_formatter(ticker.ScalarFormatter())
axis[1, 2].get_xaxis().set_major_locator(ticker.MaxNLocator(integer=True))
axis[1, 2].set_ylim(0.5,1)



#plt.suptitle('Accuracies per node in ' + MODE.upper() + ' version')
plt.savefig('results/' + MODE + '/' + MODE + '_acc_grid.svg', format='svg')
plt.show()

# %%
'''LOSSES'''

figure, axis = plt.subplots(2, 3)

'''PLOT 1'''
axis[0, 0].plot(tr_loss[RUN_NAME[0]])
axis[0, 0].plot(val_loss[RUN_NAME[0]])
axis[0, 0].legend(["Trn", "Vldt"], loc='upper right')
axis[0, 0].set_title(EXP_NAME[0])
axis[0, 0].set_xlabel("Number of rounds")
axis[0, 0].set_ylabel("Loss")
axis[0, 0].set_ylim(0,1)

'''PLOT 2'''
axis[1, 0].plot(tr_loss[RUN_NAME[1]])
axis[1, 0].plot(val_loss[RUN_NAME[1]])
axis[1, 0].legend(["Trn", "Vldt"], loc='upper right')
axis[1, 0].set_title(EXP_NAME[1])
axis[1, 0].set_xlabel("Number of rounds")
axis[1, 0].set_ylabel("Loss")
axis[1, 0].set_ylim(0,1)


'''PLOT 3'''
axis[0, 1].plot(tr_loss[RUN_NAME[2]])
axis[0, 1].plot(val_loss[RUN_NAME[2]])
axis[0, 1].legend(["Trn", "Vldt"], loc='upper right')
axis[0, 1].set_title(EXP_NAME[2])
axis[0, 1].set_xlabel("Number of rounds")
axis[0, 1].set_ylabel("Loss")
axis[0, 1].set_ylim(0,1)


'''PLOT 4'''
axis[1, 1].plot(tr_loss[RUN_NAME[3]])
axis[1, 1].plot(val_loss[RUN_NAME[3]])
axis[1, 1].legend(["Trn", "Vldt"], loc='upper right')
axis[1, 1].set_title(EXP_NAME[3])
axis[1, 1].set_xlabel("Number of rounds")
axis[1, 1].set_ylabel("Loss")
axis[1, 1].set_ylim(0,1)


'''PLOT 5'''
axis[0, 2].plot(tr_loss[RUN_NAME[4]])
axis[0, 2].plot(val_loss[RUN_NAME[4]])
axis[0, 2].legend(["Trn", "Vldt"], loc='upper right')
axis[0, 2].set_title(EXP_NAME[4])
axis[0, 2].set_xlabel("Number of rounds")
axis[0, 2].set_ylabel("Loss")
axis[0, 2].set_ylim(0,1)


'''PLOT 6'''
axis[1, 2].plot(tr_loss[RUN_NAME[5]])
axis[1, 2].plot(val_loss[RUN_NAME[5]])
axis[1, 2].legend(["Trn", "Vldt"], loc='upper right')
axis[1, 2].set_title(EXP_NAME[5])
axis[1, 2].set_xlabel("Number of rounds")
axis[1, 2].set_ylabel("Loss")
axis[1, 2].set_ylim(0,1)


#plt.suptitle('Train and Validation losses in ' + MODE.upper() + ' version')
plt.savefig('results/' + MODE + '/' + MODE + '_loss_grid.eps', format='eps')
plt.show()
# Out:
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# The PostScript backend does not support transparency; partially transparent artists will be rendered opaque.
# ...

# %%
'''PR CURVE'''

figure, axis = plt.subplots(2, 3)

'''PLOT 1'''
axis[0, 0].set_xlim(0, 1)
axis[0, 0].set_ylim(0, 1)
axis[0, 0].grid()
for i in range(0,len(cl_id[RUN_NAME[0]])):
    x = rcl[RUN_NAME[0]][i]
    y = prcsn[RUN_NAME[0]][i]
    axis[0, 0].plot(x, y, marker="p", markersize=12, markeredgecolor="black", markerfacecolor="coral")
axis[0, 0].set_title(EXP_NAME[0])
axis[0, 0].set_ylabel('Precision')
axis[0, 0].set_xlabel('Recall')
#for cli in cl_id[RUN_NAME[0]]:
#    axis[0,0].annotate(cli, (rcl[RUN_NAME[0]][cli], prcsn[RUN_NAME[0]][cli]),xytext=(-5, 6), textcoords="offset points")


'''PLOT 2'''
axis[1, 0].set_xlim(0, 1)
axis[1, 0].set_ylim(0, 1)
axis[1, 0].grid()
for i in range(0,len(cl_id[RUN_NAME[1]])):
    x = rcl[RUN_NAME[1]][i]
    y = prcsn[RUN_NAME[1]][i]
    axis[1, 0].plot(x, y, marker="p", markersize=12, markeredgecolor="black", markerfacecolor="coral")
axis[1, 0].set_title(EXP_NAME[1])
axis[1, 0].set_ylabel('Precision')
axis[1, 0].set_xlabel('Recall')
#for cli in cl_id[RUN_NAME[1]]:
#    axis[0,1].annotate(cli, (rcl[RUN_NAME[1]][cli], prcsn[RUN_NAME[1]][cli]),xytext=(-5, 6), textcoords="offset points")


'''PLOT 3'''
axis[0, 1].set_xlim(0, 1)
axis[0, 1].set_ylim(0, 1)
axis[0, 1].grid()
for i in range(0,len(cl_id[RUN_NAME[2]])):
    x = rcl[RUN_NAME[2]][i]
    y = prcsn[RUN_NAME[2]][i]
    axis[0, 1].plot(x, y, marker="p", markersize=12, markeredgecolor="black", markerfacecolor="coral")
axis[0, 1].set_title(EXP_NAME[2])
axis[0, 1].set_ylabel('Precision')
axis[0, 1].set_xlabel('Recall')
#for cli in cl_id[RUN_NAME[2]]:
#    axis[0,2].annotate(cli, (rcl[RUN_NAME[2]][cli], prcsn[RUN_NAME[2]][cli]),xytext=(-5, 6), textcoords="offset points")



'''PLOT 4'''
axis[1, 1].set_xlim(0, 1)
axis[1, 1].set_ylim(0, 1)
axis[1, 1].grid()
for i in range(0,len(cl_id[RUN_NAME[3]])):
    x = rcl[RUN_NAME[3]][i]
    y = prcsn[RUN_NAME[3]][i]
    axis[1, 1].plot(x, y, marker="p", markersize=12, markeredgecolor="black", markerfacecolor="coral")
axis[1, 1].set_title(EXP_NAME[3])
axis[1, 1].set_ylabel('Precision')
axis[1, 1].set_xlabel('Recall')
#for cli in cl_id[RUN_NAME[3]]:
#    axis[1,0].annotate(cli, (rcl[RUN_NAME[3]][cli], prcsn[RUN_NAME[3]][cli]),xytext=(-5, 6), textcoords="offset points")


'''PLOT 5'''
axis[0, 2].set_xlim(0, 1)
axis[0, 2].set_ylim(0, 1)
axis[0, 2].grid()
for i in range(0,len(cl_id[RUN_NAME[4]])):
    x = rcl[RUN_NAME[4]][i]
    y = prcsn[RUN_NAME[4]][i]
    axis[0, 2].plot(x, y, marker="p", markersize=12, markeredgecolor="black", markerfacecolor="coral")
axis[0, 2].set_title(EXP_NAME[4])
axis[0, 2].set_ylabel('Precision')
axis[0, 2].set_xlabel('Recall')
#for cli in cl_id[RUN_NAME[4]]:
#    axis[1,1].annotate(cli, (rcl[RUN_NAME[4]][cli], prcsn[RUN_NAME[4]][cli]),xytext=(-5, 6), textcoords="offset points")



'''PLOT 6'''
axis[1, 2].set_xlim(0, 1)
axis[1, 2].set_ylim(0, 1)
axis[1, 2].grid()
for i in range(0,len(cl_id[RUN_NAME[5]])):
    x = rcl[RUN_NAME[5]][i]
    y = prcsn[RUN_NAME[5]][i]
    axis[1, 2].plot(x, y, marker="p", markersize=12, markeredgecolor="black", markerfacecolor="coral")
axis[1, 2].set_title(EXP_NAME[5])
axis[1, 2].set_ylabel('Precision')
axis[1, 2].set_xlabel('Recall')
#for cli in cl_id[RUN_NAME[5]]:
#    axis[1,2].annotate(cli, (rcl[RUN_NAME[5]][cli], prcsn[RUN_NAME[5]][cli]),xytext=(-5, 6), textcoords="offset points")


#plt.suptitle('Precision-Recall points in ' + MODE.upper() + ' version')
plt.savefig('results/' + MODE + '/' + MODE + '_pr_grid.eps', format='eps')
plt.show()
